# %%
from dotenv import load_dotenv
load_dotenv()
import os

if os.environ.get("OPENAI_API_KEY"):
    print("OPENAI_API_KEY is set.")
if os.environ.get("GEMINI_API_KEY"):
    print("GEMINI_API_KEY is set.")
# Out:
# OPENAI_API_KEY is set.
# GEMINI_API_KEY is set.

# %%
# !pip install openai --quiet

# %%
import os

# Set your API key here
os.environ["OPENAI_API_KEY"] = "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"

# %%
from openai import OpenAI
import os

# Initialize client
client = OpenAI(api_key=os.environ["OPENAI_API_KEY"])

# Create embedding
response = client.embeddings.create(
    input=["I am a test string.","weather"],
    model="text-embedding-3-small"
)

# Extract vector
vector = response.data[0].embedding

# Print vector length
print("Embedding vector length:", len(vector))

# Optional: print first 10 values
print("Sample vector values:", vector[:10])
# Out:
# Embedding vector length: 1536
# Sample vector values: [0.006824493408203125, -0.0198211669921875, -0.0287628173828125, -0.0325927734375, -0.004261016845703125, -0.0115509033203125, -0.01465606689453125, 0.00804901123046875, 0.004161834716796875, -0.004779815673828125]

# %%
vector
# Out:
# [0.006824493408203125,
#  -0.0198211669921875,
#  -0.0287628173828125,
#  -0.0325927734375,
#  -0.004261016845703125,
#  -0.0115509033203125,
#  -0.01465606689453125,
#  0.00804901123046875,
#  0.004161834716796875,
#  -0.004779815673828125,
#  -0.00444793701171875,
#  -0.02825927734375,
#  -0.0269775390625,
#  0.0302581787109375,
#  0.007904052734375,
#  0.03192138671875,
#  -0.0014810562133789062,
#  0.016021728515625,
#  -0.032073974609375,
#  0.053253173828125,
#  0.040740966796875,
#  0.00295257568359375,
#  -0.0001665353775024414,
#  0.0081939697265625,
#  0.0648193359375,
#  -0.052886962890625,
#  -0.01837158203125,
#  0.0521240234375,
#  0.0295867919921875,
#  -0.040802001953125,
#  0.016998291015625,
#  -0.050262451171875,
#  -0.0276031494140625,
#  -0.031890869140625,
#  0.0233001708984375,
#  0.0404052734375,
#  0.0028476715087890625,
#  -0.0017185211181640625,
#  -0.0042572021484375,
#  -0.034637451171875,
#  -0.07037353515625,
#  0.005466461181640625,
# ...

# %%
from sklearn.metrics.pairwise import cosine_similarity

vec1 = response.data[0].embedding
vec2= response. Data[1].embedding

import numpy as np
vec1= np.array(vec1)
vec2=np.array(vec2)

def cosine_similarity(a,b):
  return np.dot(a,b)/(np.linalg.norm(a)*np.linalg.norm(b))

similarity=cosine_similarity(vec1,vec2)
print("Cosine Siilarity",similarity)
